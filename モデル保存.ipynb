# %% [markdown]
# ## 簡単な例の実装
# http://testpy.hatenablog.com/entry/2017/02/02/000000

# %%
import pandas as pd
import gym_trading
import gym
import sys
import itertools
import numpy as np
import tensorflow as tf
import tensorflow.contrib.layers as layers

import baselines.common.tf_util as U
import baselines.deepq.utils as UT

from baselines import deepq
from baselines.deepq.replay_buffer import ReplayBuffer
from baselines.common.schedules import LinearSchedule


def model(inpt, num_actions, scope, reuse=False):
    """This model takes as input an observation and returns values of all actions."""
    with tf.variable_scope(scope, reuse=reuse):
        out = inpt
        out = layers.fully_connected(out, num_outputs=128, activation_fn=tf.nn.tanh)
        out = layers.fully_connected(out, num_outputs=64, activation_fn=tf.nn.tanh)
        out = layers.fully_connected(out, num_outputs=32, activation_fn=tf.nn.tanh)
        out = layers.fully_connected(out, num_outputs=num_actions, activation_fn=None)
        return out


def run_test(env, act, episodes=1, final_test=False):
    obs = env.reset(train=False)
    start = env.sim.train_end_index + 1
    end = env.sim.count - 1

    for episode in range(episodes):
        done = False
        while done is False:
            action = act(obs[None])
            obs, reward, done, info = env.step(action)

        if not final_test:
            journal = pd.DataFrame(env.portfolio.journal)
            profit = journal["Profit"].sum()
            return env.portfolio.average_profit_per_trade, profit
        else:
            print("Training period  %s - %s" % (env.sim.date_time[start], env.sim.date_time[end]))
            print("Average Reward is %s" % (env.portfolio.average_profit_per_trade))

    if final_test:
        env.generate_summary_stats()


with U.make_session(8):
    # csv = "/home/adrian/Escritorio/polinex/EURUSD60.csv"
    csv = "data/EURUSD60.csv"

    env = gym.make('trading-v0')
    env.initialise_simulator(csv, trade_period=50, train_split=0.7)

    act, train, update_target, debug = deepq.build_train(
        make_obs_ph=lambda name: UT.BatchInput(env.observation_space.shape, name=name),
        q_func=model,
        num_actions=env.action_space.n,
        optimizer=tf.train.AdamOptimizer(learning_rate=5e-4),
    )

    replay_buffer = ReplayBuffer(50000)
    # Create the schedule for exploration starting from 1 (every action is random) down to
    # 0.02 (98% of actions are selected according to values predicted by the model).
    exploration = LinearSchedule(schedule_timesteps=10000, initial_p=1.0, final_p=0.02)
    # Initialize the parameters and copy them to the target network.
    U.initialize()
    update_target()

    episode_rewards = [0.0]
    obs = env.reset()
    l_mean_episode_reward = []
    for t in itertools.count():
        # Take action and update exploration to the newest value
        action = act(obs[None], update_eps=exploration.value(t))[0]

        new_obs, rew, done, _ = env.step(action)

        # Store transition in the replay buffer.
        replay_buffer.add(obs, action, rew, new_obs, float(done))

        obs = new_obs

        episode_rewards[-1] += rew

        is_solved = np.mean(episode_rewards[-101:-1]) > 500 or t >= 1000
        is_solved = is_solved and len(env.portfolio.journal) != 0

        if done:

            journal = pd.DataFrame(env.portfolio.journal)
            profit = journal["Profit"].sum()

            try:
                print("-------------------------------------")
                print("steps                     | {:}".format(t))
                print("episodes                  | {}".format(len(episode_rewards)))
                print("% time spent exploring    | {}".format(int(100 * exploration.value(t))))

                print("--")
                l_mean_episode_reward.append(round(np.mean(episode_rewards[-101:-1]), 1))

                print("mean episode reward       | {:}".format(l_mean_episode_reward[-1]))
                print("Total operations          | {}".format(len(env.portfolio.journal)))
                print("Avg duration trades       | {}".format(round(journal["Trade Duration"].mean(), 2)))
                print("Total profit episode      | {}".format(round(profit), 1))
                print("Avg profit per trade      | {}".format(round(env.portfolio.average_profit_per_trade, 3)))

                print("--")

                reward_test, profit = run_test(env=env, act=act)
                print("Total profit test:        > {}".format(round(profit, 2)))
                print("Avg profit per trade test > {}".format(round(reward_test, 3)))
                print("-------------------------------------")
            except Exception as e:
                print("Exception: ", e)
                # Update target network periodically.

            obs = env.reset()
            episode_rewards.append(0)



        if is_solved:
            # Show off the result
            env.generate_summary_stats()
            run_test(env, act, final_test=True)
            UT.save_state( './test_model/test_model')
            break

        else:
            # Minimize the error in Bellman's equation on a batch sampled from replay buffer.
            if t > 500:
                obses_t, actions, rewards, obses_tp1, dones = replay_buffer.sample(32)
                train(obses_t, actions, rewards, obses_tp1, dones, np.ones_like(rewards))
            if t % 500 == 0:
                update_target()
# Out:
# C:\Users\mineo\Anaconda2\envs\gym_test\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# C:\Users\mineo\Anaconda2\envs\gym_test\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The finance module has been deprecated in mpl 2.0 and will be removed in mpl 2.2. Please use the module mpl_finance instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
#                        Return       ATR  Open Trade  Duration Trade
# Date_Time
# 2013-12-02 02:00:00  0.421251  0.355142         0.0             0.0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# C:\Users\mineo\Anaconda2\envs\gym_test\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\mineo\Anaconda2\envs\gym_test\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# SUMMARY STATISTICS
# Total Trades Taken:  167
# Total Reward:  -611.1000000000129
# Average Reward per Trade:  -3.6592814371258258
# Win Ratio: 37.72455089820359 %
# [ { 'Entry Price': 1.35881,
#     'Entry Time': Timestamp('2013-12-02 03:00:00'),
#     'Exit Price': 1.35514,
#     'Exit Time': Timestamp('2013-12-02 11:00:00'),
#     'Profit': -39.70000000000062,
#     'Trade Duration': 8,
#     'Type': 'BUY',
#     'reward': -2.6000000000018204},
#   { 'Entry Price': 1.35511,
#     'Entry Time': Timestamp('2013-12-02 12:00:00'),
#     'Exit Price': 1.35405,
#     'Exit Time': Timestamp('2013-12-02 15:00:00'),
#     'Profit': -13.600000000000609,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -14.600000000000499},
#   { 'Entry Price': 1.3537700000000001,
#     'Entry Time': Timestamp('2013-12-02 22:00:00'),
#     'Exit Price': 1.35343,
#     'Exit Time': Timestamp('2013-12-03 03:00:00'),
#     'Profit': 0.4000000000022901,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -0.29999999999785487},
#   { 'Entry Price': 1.35346,
#     'Entry Time': Timestamp('2013-12-03 04:00:00'),
#     'Exit Price': 1.35362,
#     'Exit Time': Timestamp('2013-12-03 06:00:00'),
#     'Profit': -1.4000000000006203,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -4.2000000000012},
#   { 'Entry Price': 1.35446,
#     'Entry Time': Timestamp('2013-12-03 08:00:00'),
#     'Exit Price': 1.35658,
#     'Exit Time': Timestamp('2013-12-03 10:00:00'),
#     'Profit': 18.199999999998997,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -3.304023721284466e-13},
#   { 'Entry Price': 1.35713,
#     'Entry Time': Timestamp('2013-12-03 12:00:00'),
#     'Exit Price': 1.35826,
#     'Exit Time': Timestamp('2013-12-03 15:00:00'),
#     'Profit': 8.300000000000754,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -0.6999999999982549},
#   { 'Entry Price': 1.35875,
#     'Entry Time': Timestamp('2013-12-03 23:00:00'),
#     'Exit Price': 1.35879,
#     'Exit Time': Timestamp('2013-12-04 00:00:00'),
#     'Profit': -3.4000000000004,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -4.2000000000012},
#   { 'Entry Price': 1.35863,
#     'Entry Time': Timestamp('2013-12-04 03:00:00'),
#     'Exit Price': 1.35894,
#     'Exit Time': Timestamp('2013-12-04 06:00:00'),
#     'Profit': 0.10000000000032472,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -3.700000000000145},
#   { 'Entry Price': 1.35894,
#     'Entry Time': Timestamp('2013-12-04 07:00:00'),
#     'Exit Price': 1.35463,
#     'Exit Time': Timestamp('2013-12-04 15:00:00'),
#     'Profit': 40.100000000000364,
#     'Trade Duration': 8,
#     'Type': 'SELL',
#     'reward': -11.20000000000043},
#   { 'Entry Price': 1.35459,
#     'Entry Time': Timestamp('2013-12-04 16:00:00'),
#     'Exit Price': 1.35561,
#     'Exit Time': Timestamp('2013-12-04 17:00:00'),
#     'Profit': -13.200000000000209,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 0.6999999999998145},
#   { 'Entry Price': 1.35559,
#     'Entry Time': Timestamp('2013-12-04 18:00:00'),
#     'Exit Price': 1.3593899999999999,
#     'Exit Time': Timestamp('2013-12-04 19:00:00'),
#     'Profit': -40.99999999999804,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -0.9999999999979998},
#   { 'Entry Price': 1.35938,
#     'Entry Time': Timestamp('2013-12-04 20:00:00'),
#     'Exit Price': 1.35879,
#     'Exit Time': Timestamp('2013-12-04 21:00:00'),
#     'Profit': -8.900000000000905,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -9.500000000000394},
#   { 'Entry Price': 1.35853,
#     'Entry Time': Timestamp('2013-12-04 23:00:00'),
#     'Exit Price': 1.3586200000000002,
#     'Exit Time': Timestamp('2013-12-05 03:00:00'),
#     'Profit': -2.099999999998545,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -8.20000000000076},
#   { 'Entry Price': 1.3586200000000002,
#     'Entry Time': Timestamp('2013-12-05 04:00:00'),
#     'Exit Price': 1.36248,
#     'Exit Time': Timestamp('2013-12-05 08:00:00'),
#     'Profit': 35.59999999999752,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': 14.799999999998928},
#   { 'Entry Price': 1.36246,
#     'Entry Time': Timestamp('2013-12-05 09:00:00'),
#     'Exit Price': 1.3585399999999999,
#     'Exit Time': Timestamp('2013-12-05 13:00:00'),
#     'Profit': -42.20000000000145,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -29.999999999999247},
#   { 'Entry Price': 1.36151,
#     'Entry Time': Timestamp('2013-12-05 16:00:00'),
#     'Exit Price': 1.36713,
#     'Exit Time': Timestamp('2013-12-06 00:00:00'),
#     'Profit': -59.199999999999584,
#     'Trade Duration': 8,
#     'Type': 'SELL',
#     'reward': -54.499999999999886},
#   { 'Entry Price': 1.36669,
#     'Entry Time': Timestamp('2013-12-06 04:00:00'),
#     'Exit Price': 1.3663,
#     'Exit Time': Timestamp('2013-12-06 06:00:00'),
#     'Profit': -6.899999999998904,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -3.8999999999992347},
#   { 'Entry Price': 1.3655,
#     'Entry Time': Timestamp('2013-12-06 09:00:00'),
#     'Exit Price': 1.36615,
#     'Exit Time': Timestamp('2013-12-06 14:00:00'),
#     'Profit': -9.500000000000394,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -17.00000000000068},
#   { 'Entry Price': 1.36608,
#     'Entry Time': Timestamp('2013-12-06 15:00:00'),
#     'Exit Price': 1.3676,
#     'Exit Time': Timestamp('2013-12-06 16:00:00'),
#     'Profit': 12.199999999999658,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -4.80000000000069},
#   { 'Entry Price': 1.36947,
#     'Entry Time': Timestamp('2013-12-06 22:00:00'),
#     'Exit Price': 1.37069,
#     'Exit Time': Timestamp('2013-12-09 03:00:00'),
#     'Profit': -15.199999999999989,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -14.500000000002064},
#   { 'Entry Price': 1.37096,
#     'Entry Time': Timestamp('2013-12-09 05:00:00'),
#     'Exit Price': 1.37093,
#     'Exit Time': Timestamp('2013-12-09 12:00:00'),
#     'Profit': -3.299999999999745,
#     'Trade Duration': 7,
#     'Type': 'BUY',
#     'reward': 4.100000000002105},
#   { 'Entry Price': 1.37095,
#     'Entry Time': Timestamp('2013-12-09 13:00:00'),
#     'Exit Price': 1.37206,
#     'Exit Time': Timestamp('2013-12-09 15:00:00'),
#     'Profit': 8.100000000001664,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 8.900000000000244},
#   { 'Entry Price': 1.37209,
#     'Entry Time': Timestamp('2013-12-09 16:00:00'),
#     'Exit Price': 1.37245,
#     'Exit Time': Timestamp('2013-12-09 18:00:00'),
#     'Profit': -6.599999999999159,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -0.7000000000004754},
#   { 'Entry Price': 1.3724399999999999,
#     'Entry Time': Timestamp('2013-12-09 19:00:00'),
#     'Exit Price': 1.37343,
#     'Exit Time': Timestamp('2013-12-10 00:00:00'),
#     'Profit': -12.900000000000464,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -16.80000000000159},
#   { 'Entry Price': 1.37375,
#     'Entry Time': Timestamp('2013-12-10 03:00:00'),
#     'Exit Price': 1.37486,
#     'Exit Time': Timestamp('2013-12-10 09:00:00'),
#     'Profit': -14.099999999999444,
#     'Trade Duration': 6,
#     'Type': 'SELL',
#     'reward': -10.20000000000054},
#   { 'Entry Price': 1.37525,
#     'Entry Time': Timestamp('2013-12-10 11:00:00'),
#     'Exit Price': 1.37629,
#     'Exit Time': Timestamp('2013-12-10 15:00:00'),
#     'Profit': 7.399999999999299,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -4.100000000000545},
#   { 'Entry Price': 1.3763299999999998,
#     'Entry Time': Timestamp('2013-12-10 16:00:00'),
#     'Exit Price': 1.37706,
#     'Exit Time': Timestamp('2013-12-10 17:00:00'),
#     'Profit': -10.300000000001194,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -21.800000000001038},
#   { 'Entry Price': 1.37705,
#     'Entry Time': Timestamp('2013-12-10 18:00:00'),
#     'Exit Price': 1.37541,
#     'Exit Time': Timestamp('2013-12-11 03:00:00'),
#     'Profit': 13.400000000000858,
#     'Trade Duration': 9,
#     'Type': 'SELL',
#     'reward': 7.500000000002174},
#   { 'Entry Price': 1.37537,
#     'Entry Time': Timestamp('2013-12-11 04:00:00'),
#     'Exit Price': 1.37568,
#     'Exit Time': Timestamp('2013-12-11 07:00:00'),
#     'Profit': -6.100000000000325,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -7.699999999999704},
#   { 'Entry Price': 1.37622,
#     'Entry Time': Timestamp('2013-12-11 11:00:00'),
#     'Exit Price': 1.3767399999999999,
#     'Exit Time': Timestamp('2013-12-11 15:00:00'),
#     'Profit': -8.19999999999854,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -6.40000000000007},
#   { 'Entry Price': 1.3790200000000001,
#     'Entry Time': Timestamp('2013-12-11 18:00:00'),
#     'Exit Price': 1.37931,
#     'Exit Time': Timestamp('2013-12-12 06:00:00'),
#     'Profit': -0.10000000000098552,
#     'Trade Duration': 12,
#     'Type': 'BUY',
#     'reward': -2.3000000000020755},
#   { 'Entry Price': 1.37931,
#     'Entry Time': Timestamp('2013-12-12 07:00:00'),
#     'Exit Price': 1.37805,
#     'Exit Time': Timestamp('2013-12-12 08:00:00'),
#     'Profit': 9.600000000000389,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -1.2999999999999652},
#   { 'Entry Price': 1.3780299999999999,
#     'Entry Time': Timestamp('2013-12-12 09:00:00'),
#     'Exit Price': 1.37476,
#     'Exit Time': Timestamp('2013-12-13 03:00:00'),
#     'Profit': -35.69999999999884,
#     'Trade Duration': 18,
#     'Type': 'BUY',
#     'reward': -37.79999999999927},
#   { 'Entry Price': 1.37476,
#     'Entry Time': Timestamp('2013-12-13 04:00:00'),
#     'Exit Price': 1.3722,
#     'Exit Time': Timestamp('2013-12-13 13:00:00'),
#     'Profit': 22.599999999998957,
#     'Trade Duration': 9,
#     'Type': 'SELL',
#     'reward': 35.49999999999909},
#   { 'Entry Price': 1.37219,
#     'Entry Time': Timestamp('2013-12-13 14:00:00'),
#     'Exit Price': 1.37331,
#     'Exit Time': Timestamp('2013-12-13 21:00:00'),
#     'Profit': -14.200000000000099,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': -5.99999999999967},
#   { 'Entry Price': 1.3727,
#     'Entry Time': Timestamp('2013-12-16 00:00:00'),
#     'Exit Price': 1.37558,
#     'Exit Time': Timestamp('2013-12-16 04:00:00'),
#     'Profit': -31.799999999999937,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -27.100000000000232},
#   { 'Entry Price': 1.3756899999999999,
#     'Entry Time': Timestamp('2013-12-16 06:00:00'),
#     'Exit Price': 1.37551,
#     'Exit Time': Timestamp('2013-12-16 08:00:00'),
#     'Profit': -1.2000000000015305,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 1.699999999997484},
#   { 'Entry Price': 1.37497,
#     'Entry Time': Timestamp('2013-12-16 10:00:00'),
#     'Exit Price': 1.37742,
#     'Exit Time': Timestamp('2013-12-16 12:00:00'),
#     'Profit': 21.500000000000632,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 14.699999999998273},
#   { 'Entry Price': 1.3759,
#     'Entry Time': Timestamp('2013-12-16 17:00:00'),
#     'Exit Price': 1.3746,
#     'Exit Time': Timestamp('2013-12-16 19:00:00'),
#     'Profit': -15.999999999998568,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -6.299999999997194},
#   { 'Entry Price': 1.37458,
#     'Entry Time': Timestamp('2013-12-16 20:00:00'),
#     'Exit Price': 1.3762,
#     'Exit Time': Timestamp('2013-12-16 22:00:00'),
#     'Profit': 13.200000000001769,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 14.800000000001148},
#   { 'Entry Price': 1.37619,
#     'Entry Time': Timestamp('2013-12-16 23:00:00'),
#     'Exit Price': 1.37521,
#     'Exit Time': Timestamp('2013-12-17 02:00:00'),
#     'Profit': 6.799999999999809,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -0.8999999999995651},
#   { 'Entry Price': 1.37521,
#     'Entry Time': Timestamp('2013-12-17 03:00:00'),
#     'Exit Price': 1.37626,
#     'Exit Time': Timestamp('2013-12-17 04:00:00'),
#     'Profit': 7.499999999999954,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': 4.399999999999629},
#   { 'Entry Price': 1.37663,
#     'Entry Time': Timestamp('2013-12-17 06:00:00'),
#     'Exit Price': 1.37354,
#     'Exit Time': Timestamp('2013-12-17 16:00:00'),
#     'Profit': -33.900000000000375,
#     'Trade Duration': 10,
#     'Type': 'BUY',
#     'reward': -11.799999999999919},
#   { 'Entry Price': 1.3735600000000001,
#     'Entry Time': Timestamp('2013-12-17 17:00:00'),
#     'Exit Price': 1.3765399999999999,
#     'Exit Time': Timestamp('2013-12-17 21:00:00'),
#     'Profit': -32.79999999999761,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -33.699999999999065},
#   { 'Entry Price': 1.37669,
#     'Entry Time': Timestamp('2013-12-18 00:00:00'),
#     'Exit Price': 1.37501,
#     'Exit Time': Timestamp('2013-12-18 12:00:00'),
#     'Profit': 13.799999999999038,
#     'Trade Duration': 12,
#     'Type': 'SELL',
#     'reward': 16.000000000000128},
#   { 'Entry Price': 1.37499,
#     'Entry Time': Timestamp('2013-12-18 13:00:00'),
#     'Exit Price': 1.37605,
#     'Exit Time': Timestamp('2013-12-18 17:00:00'),
#     'Profit': -13.600000000000609,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -18.499999999999403},
#   { 'Entry Price': 1.3764100000000001,
#     'Entry Time': Timestamp('2013-12-18 19:00:00'),
#     'Exit Price': 1.36932,
#     'Exit Time': Timestamp('2013-12-18 22:00:00'),
#     'Profit': -73.9000000000004,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -10.900000000000684},
#   { 'Entry Price': 1.3693,
#     'Entry Time': Timestamp('2013-12-18 23:00:00'),
#     'Exit Price': 1.36774,
#     'Exit Time': Timestamp('2013-12-19 10:00:00'),
#     'Profit': 12.600000000000058,
#     'Trade Duration': 11,
#     'Type': 'SELL',
#     'reward': 2.799999999998022},
#   { 'Entry Price': 1.36773,
#     'Entry Time': Timestamp('2013-12-19 11:00:00'),
#     'Exit Price': 1.36706,
#     'Exit Time': Timestamp('2013-12-19 15:00:00'),
#     'Profit': 3.699999999999484,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': 12.499999999999403},
#   { 'Entry Price': 1.36707,
#     'Entry Time': Timestamp('2013-12-19 16:00:00'),
#     'Exit Price': 1.36646,
#     'Exit Time': Timestamp('2013-12-19 18:00:00'),
#     'Profit': 3.0999999999999943,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 0.2999999999994145},
#   { 'Entry Price': 1.36646,
#     'Entry Time': Timestamp('2013-12-19 19:00:00'),
#     'Exit Price': 1.36351,
#     'Exit Time': Timestamp('2013-12-20 06:00:00'),
#     'Profit': -32.500000000000085,
#     'Trade Duration': 11,
#     'Type': 'BUY',
#     'reward': -23.899999999999253},
#   { 'Entry Price': 1.36351,
#     'Entry Time': Timestamp('2013-12-20 07:00:00'),
#     'Exit Price': 1.36582,
#     'Exit Time': Timestamp('2013-12-20 12:00:00'),
#     'Profit': -26.100000000000342,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -12.799999999999809},
#   { 'Entry Price': 1.36515,
#     'Entry Time': Timestamp('2013-12-20 14:00:00'),
#     'Exit Price': 1.3673899999999999,
#     'Exit Time': Timestamp('2013-12-20 16:00:00'),
#     'Profit': -25.399999999997977,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 5.000000000001339},
#   { 'Entry Price': 1.3673799999999998,
#     'Entry Time': Timestamp('2013-12-20 17:00:00'),
#     'Exit Price': 1.36772,
#     'Exit Time': Timestamp('2013-12-20 19:00:00'),
#     'Profit': -6.40000000000229,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -1.2000000000015305},
#   { 'Entry Price': 1.3676700000000002,
#     'Entry Time': Timestamp('2013-12-20 20:00:00'),
#     'Exit Price': 1.36772,
#     'Exit Time': Timestamp('2013-12-23 06:00:00'),
#     'Profit': -3.4999999999988347,
#     'Trade Duration': 10,
#     'Type': 'SELL',
#     'reward': -0.4999999999991651},
#   { 'Entry Price': 1.36774,
#     'Entry Time': Timestamp('2013-12-23 11:00:00'),
#     'Exit Price': 1.36791,
#     'Exit Time': Timestamp('2013-12-23 12:00:00'),
#     'Profit': -1.2999999999999652,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -4.100000000000545},
#   { 'Entry Price': 1.3695899999999999,
#     'Entry Time': Timestamp('2013-12-23 15:00:00'),
#     'Exit Price': 1.36975,
#     'Exit Time': Timestamp('2013-12-23 16:00:00'),
#     'Profit': -4.6000000000016,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -8.60000000000116},
#   { 'Entry Price': 1.37047,
#     'Entry Time': Timestamp('2013-12-23 18:00:00'),
#     'Exit Price': 1.3696,
#     'Exit Time': Timestamp('2013-12-23 20:00:00'),
#     'Profit': 5.700000000001484,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 3.5000000000003944},
#   { 'Entry Price': 1.36947,
#     'Entry Time': Timestamp('2013-12-24 01:00:00'),
#     'Exit Price': 1.36845,
#     'Exit Time': Timestamp('2013-12-24 02:00:00'),
#     'Profit': -13.200000000000209,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -1.4000000000006203},
#   { 'Entry Price': 1.3684399999999999,
#     'Entry Time': Timestamp('2013-12-24 03:00:00'),
#     'Exit Price': 1.3682,
#     'Exit Time': Timestamp('2013-12-24 05:00:00'),
#     'Profit': -0.6000000000020407,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -1.4000000000006203},
#   { 'Entry Price': 1.3684399999999999,
#     'Entry Time': Timestamp('2013-12-24 09:00:00'),
#     'Exit Price': 1.36789,
#     'Exit Time': Timestamp('2013-12-24 11:00:00'),
#     'Profit': 2.499999999998284,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 7.9999999999987885},
#   { 'Entry Price': 1.3678700000000001,
#     'Entry Time': Timestamp('2013-12-24 14:00:00'),
#     'Exit Price': 1.3663399999999999,
#     'Exit Time': Timestamp('2013-12-24 16:00:00'),
#     'Profit': 12.300000000002534,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 5.900000000002795},
#   { 'Entry Price': 1.3684399999999999,
#     'Entry Time': Timestamp('2013-12-26 09:00:00'),
#     'Exit Price': 1.36916,
#     'Exit Time': Timestamp('2013-12-26 11:00:00'),
#     'Profit': -10.20000000000054,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -4.100000000000545},
#   { 'Entry Price': 1.36916,
#     'Entry Time': Timestamp('2013-12-26 12:00:00'),
#     'Exit Price': 1.3688200000000001,
#     'Exit Time': Timestamp('2013-12-26 14:00:00'),
#     'Profit': 0.3999999999978492,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -6.60000000000138},
#   { 'Entry Price': 1.3686200000000002,
#     'Entry Time': Timestamp('2013-12-26 17:00:00'),
#     'Exit Price': 1.36916,
#     'Exit Time': Timestamp('2013-12-26 20:00:00'),
#     'Profit': 2.399999999997629,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 0.09999999999810427},
#   { 'Entry Price': 1.36915,
#     'Entry Time': Timestamp('2013-12-26 21:00:00'),
#     'Exit Price': 1.37047,
#     'Exit Time': Timestamp('2013-12-27 02:00:00'),
#     'Profit': -16.19999999999988,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -5.100000000000435},
#   { 'Entry Price': 1.37045,
#     'Entry Time': Timestamp('2013-12-27 03:00:00'),
#     'Exit Price': 1.37362,
#     'Exit Time': Timestamp('2013-12-27 06:00:00'),
#     'Profit': -34.70000000000117,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -32.60000000000073},
#   { 'Entry Price': 1.3746399999999999,
#     'Entry Time': Timestamp('2013-12-27 08:00:00'),
#     'Exit Price': 1.3794899999999999,
#     'Exit Time': Timestamp('2013-12-27 10:00:00'),
#     'Profit': -51.50000000000021,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -20.20000000000166},
#   { 'Entry Price': 1.37953,
#     'Entry Time': Timestamp('2013-12-27 11:00:00'),
#     'Exit Price': 1.38444,
#     'Exit Time': Timestamp('2013-12-27 14:00:00'),
#     'Profit': -52.099999999999696,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -67.20000000000093},
#   { 'Entry Price': 1.38162,
#     'Entry Time': Timestamp('2013-12-27 16:00:00'),
#     'Exit Price': 1.37478,
#     'Exit Time': Timestamp('2013-12-27 23:00:00'),
#     'Profit': 65.4000000000018,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': 73.90000000000197},
#   { 'Entry Price': 1.3760700000000001,
#     'Entry Time': Timestamp('2013-12-30 01:00:00'),
#     'Exit Price': 1.37696,
#     'Exit Time': Timestamp('2013-12-30 14:00:00'),
#     'Profit': 5.899999999998354,
#     'Trade Duration': 13,
#     'Type': 'BUY',
#     'reward': -2.2000000000014204},
#   { 'Entry Price': 1.38038,
#     'Entry Time': Timestamp('2013-12-30 21:00:00'),
#     'Exit Price': 1.37972,
#     'Exit Time': Timestamp('2013-12-30 22:00:00'),
#     'Profit': -9.599999999998829,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -6.40000000000007},
#   { 'Entry Price': 1.3797,
#     'Entry Time': Timestamp('2013-12-30 23:00:00'),
#     'Exit Price': 1.37932,
#     'Exit Time': Timestamp('2013-12-31 00:00:00'),
#     'Profit': 0.7999999999982492,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -7.100000000000215},
#   { 'Entry Price': 1.37932,
#     'Entry Time': Timestamp('2013-12-31 01:00:00'),
#     'Exit Price': 1.37658,
#     'Exit Time': Timestamp('2013-12-31 13:00:00'),
#     'Profit': 24.400000000001867,
#     'Trade Duration': 12,
#     'Type': 'SELL',
#     'reward': 27.49999999999997},
#   { 'Entry Price': 1.37713,
#     'Entry Time': Timestamp('2013-12-31 15:00:00'),
#     'Exit Price': 1.37742,
#     'Exit Time': Timestamp('2013-12-31 16:00:00'),
#     'Profit': -5.900000000001235,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -9.300000000001305},
#   { 'Entry Price': 1.37754,
#     'Entry Time': Timestamp('2013-12-31 17:00:00'),
#     'Exit Price': 1.3777700000000002,
#     'Exit Time': Timestamp('2013-12-31 18:00:00'),
#     'Profit': -5.300000000001745,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -6.899999999998904},
#   { 'Entry Price': 1.37871,
#     'Entry Time': Timestamp('2013-12-31 20:00:00'),
#     'Exit Price': 1.37589,
#     'Exit Time': Timestamp('2014-01-02 00:00:00'),
#     'Profit': 25.200000000000447,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 6.900000000000464},
#   { 'Entry Price': 1.37637,
#     'Entry Time': Timestamp('2014-01-02 02:00:00'),
#     'Exit Price': 1.37652,
#     'Exit Time': Timestamp('2014-01-02 04:00:00'),
#     'Profit': -1.5000000000012754,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -4.500000000000945},
#   { 'Entry Price': 1.37268,
#     'Entry Time': Timestamp('2014-01-02 11:00:00'),
#     'Exit Price': 1.36459,
#     'Exit Time': Timestamp('2014-01-02 16:00:00'),
#     'Profit': 77.89999999999931,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': 73.29999999999804},
#   { 'Entry Price': 1.3646,
#     'Entry Time': Timestamp('2014-01-02 17:00:00'),
#     'Exit Price': 1.3673600000000001,
#     'Exit Time': Timestamp('2014-01-02 19:00:00'),
#     'Profit': 24.600000000000957,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 19.799999999998377},
#   { 'Entry Price': 1.36666,
#     'Entry Time': Timestamp('2014-01-02 21:00:00'),
#     'Exit Price': 1.36538,
#     'Exit Time': Timestamp('2014-01-03 03:00:00'),
#     'Profit': 9.799999999999478,
#     'Trade Duration': 6,
#     'Type': 'SELL',
#     'reward': 3.699999999999484},
#   { 'Entry Price': 1.36571,
#     'Entry Time': Timestamp('2014-01-03 06:00:00'),
#     'Exit Price': 1.365,
#     'Exit Time': Timestamp('2014-01-03 09:00:00'),
#     'Profit': 4.099999999999884,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': 2.899999999998684},
#   { 'Entry Price': 1.36499,
#     'Entry Time': Timestamp('2014-01-03 10:00:00'),
#     'Exit Price': 1.36459,
#     'Exit Time': Timestamp('2014-01-03 11:00:00'),
#     'Profit': 0.9999999999995595,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 8.699999999998933},
#   { 'Entry Price': 1.36459,
#     'Entry Time': Timestamp('2014-01-03 12:00:00'),
#     'Exit Price': 1.36119,
#     'Exit Time': Timestamp('2014-01-03 17:00:00'),
#     'Profit': 31.000000000000696,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': 34.30000000000011},
#   { 'Entry Price': 1.36037,
#     'Entry Time': Timestamp('2014-01-03 19:00:00'),
#     'Exit Price': 1.35978,
#     'Exit Time': Timestamp('2014-01-03 21:00:00'),
#     'Profit': -8.900000000000905,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -4.700000000000035},
#   { 'Entry Price': 1.35979,
#     'Entry Time': Timestamp('2014-01-03 22:00:00'),
#     'Exit Price': 1.35786,
#     'Exit Time': Timestamp('2014-01-06 07:00:00'),
#     'Profit': 16.299999999999873,
#     'Trade Duration': 9,
#     'Type': 'SELL',
#     'reward': 13.199999999999548},
#   { 'Entry Price': 1.3594600000000001,
#     'Entry Time': Timestamp('2014-01-06 11:00:00'),
#     'Exit Price': 1.36376,
#     'Exit Time': Timestamp('2014-01-06 19:00:00'),
#     'Profit': 39.9999999999997,
#     'Trade Duration': 8,
#     'Type': 'BUY',
#     'reward': 36.89999999999938},
#   { 'Entry Price': 1.3637700000000001,
#     'Entry Time': Timestamp('2014-01-06 20:00:00'),
#     'Exit Price': 1.3632600000000001,
#     'Exit Time': Timestamp('2014-01-07 00:00:00'),
#     'Profit': -8.100000000000104,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -13.80000000000192},
#   { 'Entry Price': 1.36287,
#     'Entry Time': Timestamp('2014-01-07 02:00:00'),
#     'Exit Price': 1.36237,
#     'Exit Time': Timestamp('2014-01-07 05:00:00'),
#     'Profit': 1.9999999999994493,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -0.8999999999995651},
#   { 'Entry Price': 1.36235,
#     'Entry Time': Timestamp('2014-01-07 07:00:00'),
#     'Exit Price': 1.36267,
#     'Exit Time': Timestamp('2014-01-07 10:00:00'),
#     'Profit': 0.20000000000097984,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -8.99999999999934},
#   { 'Entry Price': 1.36267,
#     'Entry Time': Timestamp('2014-01-07 11:00:00'),
#     'Exit Price': 1.36418,
#     'Exit Time': Timestamp('2014-01-07 14:00:00'),
#     'Profit': -18.099999999999003,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -12.00000000000123},
#   { 'Entry Price': 1.3642,
#     'Entry Time': Timestamp('2014-01-07 15:00:00'),
#     'Exit Price': 1.36209,
#     'Exit Time': Timestamp('2014-01-07 16:00:00'),
#     'Profit': 18.100000000000563,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 10.900000000000023},
#   { 'Entry Price': 1.36209,
#     'Entry Time': Timestamp('2014-01-07 17:00:00'),
#     'Exit Price': 1.36164,
#     'Exit Time': Timestamp('2014-01-07 20:00:00'),
#     'Profit': 1.5000000000006146,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -10.599999999998719},
#   { 'Entry Price': 1.36165,
#     'Entry Time': Timestamp('2014-01-07 21:00:00'),
#     'Exit Price': 1.3613,
#     'Exit Time': Timestamp('2014-01-08 00:00:00'),
#     'Profit': -6.500000000000725,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -5.60000000000149},
#   { 'Entry Price': 1.36156,
#     'Entry Time': Timestamp('2014-01-08 02:00:00'),
#     'Exit Price': 1.3627,
#     'Exit Time': Timestamp('2014-01-08 03:00:00'),
#     'Profit': -14.399999999999189,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 5.8000000000021394},
#   { 'Entry Price': 1.36271,
#     'Entry Time': Timestamp('2014-01-08 04:00:00'),
#     'Exit Price': 1.36287,
#     'Exit Time': Timestamp('2014-01-08 07:00:00'),
#     'Profit': -4.59999999999938,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -6.9999999999995595},
#   { 'Entry Price': 1.36168,
#     'Entry Time': Timestamp('2014-01-08 10:00:00'),
#     'Exit Price': 1.35991,
#     'Exit Time': Timestamp('2014-01-08 17:00:00'),
#     'Profit': 14.700000000000493,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': 14.300000000000093},
#   { 'Entry Price': 1.35694,
#     'Entry Time': Timestamp('2014-01-08 20:00:00'),
#     'Exit Price': 1.35704,
#     'Exit Time': Timestamp('2014-01-09 01:00:00'),
#     'Profit': -3.99999999999989,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -7.599999999999049},
#   { 'Entry Price': 1.35705,
#     'Entry Time': Timestamp('2014-01-09 02:00:00'),
#     'Exit Price': 1.35763,
#     'Exit Time': Timestamp('2014-01-09 04:00:00'),
#     'Profit': -8.799999999998029,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -10.099999999999884},
#   { 'Entry Price': 1.3587,
#     'Entry Time': Timestamp('2014-01-09 08:00:00'),
#     'Exit Price': 1.36053,
#     'Exit Time': Timestamp('2014-01-10 01:00:00'),
#     'Profit': 15.299999999999983,
#     'Trade Duration': 17,
#     'Type': 'BUY',
#     'reward': 11.000000000000682},
#   { 'Entry Price': 1.36119,
#     'Entry Time': Timestamp('2014-01-10 07:00:00'),
#     'Exit Price': 1.36093,
#     'Exit Time': Timestamp('2014-01-10 08:00:00'),
#     'Profit': -5.59999999999927,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -1.7999999999988},
#   { 'Entry Price': 1.3604399999999999,
#     'Entry Time': Timestamp('2014-01-10 11:00:00'),
#     'Exit Price': 1.3594700000000002,
#     'Exit Time': Timestamp('2014-01-10 13:00:00'),
#     'Profit': 6.699999999996933,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 11.799999999999258},
#   { 'Entry Price': 1.35887,
#     'Entry Time': Timestamp('2014-01-10 15:00:00'),
#     'Exit Price': 1.36611,
#     'Exit Time': Timestamp('2014-01-10 18:00:00'),
#     'Profit': 69.39999999999912,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 79.89999999999908},
#   { 'Entry Price': 1.3661,
#     'Entry Time': Timestamp('2014-01-10 19:00:00'),
#     'Exit Price': 1.36701,
#     'Exit Time': Timestamp('2014-01-10 20:00:00'),
#     'Profit': -12.099999999999664,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -4.100000000000545},
#   { 'Entry Price': 1.367,
#     'Entry Time': Timestamp('2014-01-10 21:00:00'),
#     'Exit Price': 1.36638,
#     'Exit Time': Timestamp('2014-01-10 22:00:00'),
#     'Profit': 3.2000000000006494,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 7.299999999998644},
#   { 'Entry Price': 1.36639,
#     'Entry Time': Timestamp('2014-01-10 23:00:00'),
#     'Exit Price': 1.36742,
#     'Exit Time': Timestamp('2014-01-13 04:00:00'),
#     'Profit': -13.300000000000864,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -2.700000000000255},
#   { 'Entry Price': 1.36745,
#     'Entry Time': Timestamp('2014-01-13 05:00:00'),
#     'Exit Price': 1.36781,
#     'Exit Time': Timestamp('2014-01-13 06:00:00'),
#     'Profit': 0.5999999999991594,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': 4.099999999999884},
#   { 'Entry Price': 1.36758,
#     'Entry Time': Timestamp('2014-01-13 08:00:00'),
#     'Exit Price': 1.36658,
#     'Exit Time': Timestamp('2014-01-13 10:00:00'),
#     'Profit': -13.000000000001119,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -4.500000000000945},
#   { 'Entry Price': 1.36657,
#     'Entry Time': Timestamp('2014-01-13 11:00:00'),
#     'Exit Price': 1.36655,
#     'Exit Time': Timestamp('2014-01-13 14:00:00'),
#     'Profit': -2.7999999999986898,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -2.5000000000011653},
#   { 'Entry Price': 1.36653,
#     'Entry Time': Timestamp('2014-01-13 15:00:00'),
#     'Exit Price': 1.36522,
#     'Exit Time': Timestamp('2014-01-13 16:00:00'),
#     'Profit': 10.099999999999223,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 17.099999999998452},
#   { 'Entry Price': 1.36523,
#     'Entry Time': Timestamp('2014-01-13 18:00:00'),
#     'Exit Price': 1.3656700000000002,
#     'Exit Time': Timestamp('2014-01-13 20:00:00'),
#     'Profit': -7.40000000000218,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -3.3000000000019654},
#   { 'Entry Price': 1.36568,
#     'Entry Time': Timestamp('2014-01-13 21:00:00'),
#     'Exit Price': 1.3663,
#     'Exit Time': Timestamp('2014-01-14 04:00:00'),
#     'Profit': 3.2000000000006494,
#     'Trade Duration': 7,
#     'Type': 'BUY',
#     'reward': -3.900000000001455},
#   { 'Entry Price': 1.3663,
#     'Entry Time': Timestamp('2014-01-14 05:00:00'),
#     'Exit Price': 1.36642,
#     'Exit Time': Timestamp('2014-01-14 06:00:00'),
#     'Profit': -1.8000000000010203,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -5.299999999999525},
#   { 'Entry Price': 1.36642,
#     'Entry Time': Timestamp('2014-01-14 07:00:00'),
#     'Exit Price': 1.36624,
#     'Exit Time': Timestamp('2014-01-14 08:00:00'),
#     'Profit': -1.19999999999931,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -3.700000000000145},
#   { 'Entry Price': 1.36742,
#     'Entry Time': Timestamp('2014-01-14 13:00:00'),
#     'Exit Price': 1.36653,
#     'Exit Time': Timestamp('2014-01-14 15:00:00'),
#     'Profit': -11.900000000000574,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -6.60000000000138},
#   { 'Entry Price': 1.3674600000000001,
#     'Entry Time': Timestamp('2014-01-14 21:00:00'),
#     'Exit Price': 1.36779,
#     'Exit Time': Timestamp('2014-01-14 23:00:00'),
#     'Profit': -6.2999999999994145,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -8.100000000000104},
#   { 'Entry Price': 1.36778,
#     'Entry Time': Timestamp('2014-01-15 00:00:00'),
#     'Exit Price': 1.3666,
#     'Exit Time': Timestamp('2014-01-15 01:00:00'),
#     'Profit': 8.799999999999589,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 3.5000000000003944},
#   { 'Entry Price': 1.36706,
#     'Entry Time': Timestamp('2014-01-15 03:00:00'),
#     'Exit Price': 1.36385,
#     'Exit Time': Timestamp('2014-01-15 08:00:00'),
#     'Profit': -35.099999999999355,
#     'Trade Duration': 5,
#     'Type': 'BUY',
#     'reward': -39.79999999999906},
#   { 'Entry Price': 1.36386,
#     'Entry Time': Timestamp('2014-01-15 09:00:00'),
#     'Exit Price': 1.36163,
#     'Exit Time': Timestamp('2014-01-15 13:00:00'),
#     'Profit': -25.300000000001763,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -21.100000000000893},
#   { 'Entry Price': 1.35924,
#     'Entry Time': Timestamp('2014-01-15 21:00:00'),
#     'Exit Price': 1.3603,
#     'Exit Time': Timestamp('2014-01-15 22:00:00'),
#     'Profit': -13.600000000000609,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -10.20000000000054},
#   { 'Entry Price': 1.36039,
#     'Entry Time': Timestamp('2014-01-16 00:00:00'),
#     'Exit Price': 1.36172,
#     'Exit Time': Timestamp('2014-01-16 03:00:00'),
#     'Profit': -16.300000000000534,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': 4.500000000000284},
#   { 'Entry Price': 1.36172,
#     'Entry Time': Timestamp('2014-01-16 04:00:00'),
#     'Exit Price': 1.36135,
#     'Exit Time': Timestamp('2014-01-16 12:00:00'),
#     'Profit': -6.6999999999998145,
#     'Trade Duration': 8,
#     'Type': 'BUY',
#     'reward': 1.5999999999990493},
#   { 'Entry Price': 1.36135,
#     'Entry Time': Timestamp('2014-01-16 13:00:00'),
#     'Exit Price': 1.3601,
#     'Exit Time': Timestamp('2014-01-16 14:00:00'),
#     'Profit': 9.499999999999734,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -0.09999999999876508},
#   { 'Entry Price': 1.35922,
#     'Entry Time': Timestamp('2014-01-16 20:00:00'),
#     'Exit Price': 1.36185,
#     'Exit Time': Timestamp('2014-01-16 23:00:00'),
#     'Profit': 23.299999999999102,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 23.199999999998447},
#   { 'Entry Price': 1.36156,
#     'Entry Time': Timestamp('2014-01-17 01:00:00'),
#     'Exit Price': 1.36153,
#     'Exit Time': Timestamp('2014-01-17 04:00:00'),
#     'Profit': -2.6999999999980346,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': 0.40000000000006963},
#   { 'Entry Price': 1.36122,
#     'Entry Time': Timestamp('2014-01-17 07:00:00'),
#     'Exit Price': 1.3595,
#     'Exit Time': Timestamp('2014-01-17 14:00:00'),
#     'Profit': 14.200000000001658,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': 13.700000000000603},
#   { 'Entry Price': 1.35951,
#     'Entry Time': Timestamp('2014-01-17 15:00:00'),
#     'Exit Price': 1.35774,
#     'Exit Time': Timestamp('2014-01-17 16:00:00'),
#     'Profit': -20.700000000000493,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -20.700000000000493},
#   { 'Entry Price': 1.3556,
#     'Entry Time': Timestamp('2014-01-17 18:00:00'),
#     'Exit Price': 1.35309,
#     'Exit Time': Timestamp('2014-01-17 19:00:00'),
#     'Profit': -28.100000000000122,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -6.599999999999159},
#   { 'Entry Price': 1.3530799999999998,
#     'Entry Time': Timestamp('2014-01-17 20:00:00'),
#     'Exit Price': 1.35304,
#     'Exit Time': Timestamp('2014-01-17 21:00:00'),
#     'Profit': -2.6000000000018204,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 3.5999999999966086},
#   { 'Entry Price': 1.35261,
#     'Entry Time': Timestamp('2014-01-17 23:00:00'),
#     'Exit Price': 1.35264,
#     'Exit Time': Timestamp('2014-01-20 01:00:00'),
#     'Profit': -2.700000000000255,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 2.599999999998939},
#   { 'Entry Price': 1.35395,
#     'Entry Time': Timestamp('2014-01-20 09:00:00'),
#     'Exit Price': 1.35501,
#     'Exit Time': Timestamp('2014-01-20 12:00:00'),
#     'Profit': 7.600000000000609,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 11.700000000000824},
#   { 'Entry Price': 1.355,
#     'Entry Time': Timestamp('2014-01-20 13:00:00'),
#     'Exit Price': 1.35594,
#     'Exit Time': Timestamp('2014-01-20 16:00:00'),
#     'Profit': -12.399999999999409,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -9.20000000000065},
#   { 'Entry Price': 1.3564,
#     'Entry Time': Timestamp('2014-01-20 23:00:00'),
#     'Exit Price': 1.35448,
#     'Exit Time': Timestamp('2014-01-21 01:00:00'),
#     'Profit': -22.200000000001438,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -12.200000000000319},
#   { 'Entry Price': 1.3544100000000001,
#     'Entry Time': Timestamp('2014-01-21 02:00:00'),
#     'Exit Price': 1.35489,
#     'Exit Time': Timestamp('2014-01-21 04:00:00'),
#     'Profit': -7.799999999998139,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -10.899999999998464},
#   { 'Entry Price': 1.35491,
#     'Entry Time': Timestamp('2014-01-21 05:00:00'),
#     'Exit Price': 1.3536700000000002,
#     'Exit Time': Timestamp('2014-01-21 10:00:00'),
#     'Profit': -15.399999999999078,
#     'Trade Duration': 5,
#     'Type': 'BUY',
#     'reward': -6.300000000001635},
#   { 'Entry Price': 1.35589,
#     'Entry Time': Timestamp('2014-01-21 19:00:00'),
#     'Exit Price': 1.35589,
#     'Exit Time': Timestamp('2014-01-21 22:00:00'),
#     'Profit': -3.0,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -2.700000000000255},
#   { 'Entry Price': 1.35591,
#     'Entry Time': Timestamp('2014-01-21 23:00:00'),
#     'Exit Price': 1.35584,
#     'Exit Time': Timestamp('2014-01-22 00:00:00'),
#     'Profit': -2.299999999999855,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -3.6000000000017103},
#   { 'Entry Price': 1.35581,
#     'Entry Time': Timestamp('2014-01-22 01:00:00'),
#     'Exit Price': 1.35687,
#     'Exit Time': Timestamp('2014-01-22 02:00:00'),
#     'Profit': -13.600000000000609,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -1.4000000000006203},
#   { 'Entry Price': 1.35687,
#     'Entry Time': Timestamp('2014-01-22 03:00:00'),
#     'Exit Price': 1.35689,
#     'Exit Time': Timestamp('2014-01-22 05:00:00'),
#     'Profit': -2.80000000000091,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -3.100000000000655},
#   { 'Entry Price': 1.35622,
#     'Entry Time': Timestamp('2014-01-22 07:00:00'),
#     'Exit Price': 1.35538,
#     'Exit Time': Timestamp('2014-01-22 08:00:00'),
#     'Profit': -11.399999999999519,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -11.699999999999264},
#   { 'Entry Price': 1.35451,
#     'Entry Time': Timestamp('2014-01-22 19:00:00'),
#     'Exit Price': 1.35451,
#     'Exit Time': Timestamp('2014-01-22 20:00:00'),
#     'Profit': -3.0,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -7.299999999999304},
#   { 'Entry Price': 1.3545200000000002,
#     'Entry Time': Timestamp('2014-01-22 21:00:00'),
#     'Exit Price': 1.3546200000000002,
#     'Exit Time': Timestamp('2014-01-22 23:00:00'),
#     'Profit': -3.99999999999989,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -4.299999999997414},
#   { 'Entry Price': 1.35461,
#     'Entry Time': Timestamp('2014-01-23 00:00:00'),
#     'Exit Price': 1.35436,
#     'Exit Time': Timestamp('2014-01-23 05:00:00'),
#     'Profit': -0.4999999999991651,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -2.6999999999980346},
#   { 'Entry Price': 1.35438,
#     'Entry Time': Timestamp('2014-01-23 06:00:00'),
#     'Exit Price': 1.3543399999999999,
#     'Exit Time': Timestamp('2014-01-23 07:00:00'),
#     'Profit': -2.5999999999996,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -3.0},
#   { 'Entry Price': 1.3638,
#     'Entry Time': Timestamp('2014-01-23 12:00:00'),
#     'Exit Price': 1.36656,
#     'Exit Time': Timestamp('2014-01-23 15:00:00'),
#     'Profit': 24.600000000000957,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -2.7999999999986898},
#   { 'Entry Price': 1.36658,
#     'Entry Time': Timestamp('2014-01-23 16:00:00'),
#     'Exit Price': 1.36741,
#     'Exit Time': Timestamp('2014-01-23 19:00:00'),
#     'Profit': -11.300000000001084,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -15.800000000001699},
#   { 'Entry Price': 1.36924,
#     'Entry Time': Timestamp('2014-01-23 21:00:00'),
#     'Exit Price': 1.36824,
#     'Exit Time': Timestamp('2014-01-24 04:00:00'),
#     'Profit': 7.000000000001119,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': 7.399999999999299},
#   { 'Entry Price': 1.36835,
#     'Entry Time': Timestamp('2014-01-24 06:00:00'),
#     'Exit Price': 1.36711,
#     'Exit Time': Timestamp('2014-01-24 10:00:00'),
#     'Profit': 9.399999999999078,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -5.60000000000149},
#   { 'Entry Price': 1.36713,
#     'Entry Time': Timestamp('2014-01-24 11:00:00'),
#     'Exit Price': 1.3683,
#     'Exit Time': Timestamp('2014-01-24 16:00:00'),
#     'Profit': -14.700000000001154,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -20.499999999999186},
#   { 'Entry Price': 1.36827,
#     'Entry Time': Timestamp('2014-01-24 17:00:00'),
#     'Exit Price': 1.3686,
#     'Exit Time': Timestamp('2014-01-27 01:00:00'),
#     'Profit': 0.2999999999994145,
#     'Trade Duration': 8,
#     'Type': 'BUY',
#     'reward': -5.100000000000435},
#   { 'Entry Price': 1.36801,
#     'Entry Time': Timestamp('2014-01-27 03:00:00'),
#     'Exit Price': 1.36816,
#     'Exit Time': Timestamp('2014-01-27 05:00:00'),
#     'Profit': -1.499999999999055,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 1.6000000000012697},
#   { 'Entry Price': 1.36812,
#     'Entry Time': Timestamp('2014-01-27 07:00:00'),
#     'Exit Price': 1.36785,
#     'Exit Time': Timestamp('2014-01-27 08:00:00'),
#     'Profit': -5.699999999999925,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.299999999999855},
#   { 'Entry Price': 1.3693799999999998,
#     'Entry Time': Timestamp('2014-01-27 12:00:00'),
#     'Exit Price': 1.36595,
#     'Exit Time': Timestamp('2014-01-27 14:00:00'),
#     'Profit': -37.29999999999822,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -25.899999999999032},
#   { 'Entry Price': 1.36594,
#     'Entry Time': Timestamp('2014-01-27 15:00:00'),
#     'Exit Price': 1.3662,
#     'Exit Time': Timestamp('2014-01-27 16:00:00'),
#     'Profit': -5.60000000000149,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -1.899999999999455},
#   { 'Entry Price': 1.36619,
#     'Entry Time': Timestamp('2014-01-27 17:00:00'),
#     'Exit Price': 1.3672,
#     'Exit Time': Timestamp('2014-01-27 22:00:00'),
#     'Profit': -13.099999999999554,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -5.8999999999990145},
#   { 'Entry Price': 1.3671799999999998,
#     'Entry Time': Timestamp('2014-01-28 00:00:00'),
#     'Exit Price': 1.3670200000000001,
#     'Exit Time': Timestamp('2014-01-28 02:00:00'),
#     'Profit': -4.599999999997159,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -1.499999999999055},
#   { 'Entry Price': 1.3676700000000002,
#     'Entry Time': Timestamp('2014-01-28 08:00:00'),
#     'Exit Price': 1.36379,
#     'Exit Time': Timestamp('2014-01-28 12:00:00'),
#     'Profit': -41.800000000001056,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -29.300000000001322},
#   { 'Entry Price': 1.36379,
#     'Entry Time': Timestamp('2014-01-28 13:00:00'),
#     'Exit Price': 1.36418,
#     'Exit Time': Timestamp('2014-01-28 14:00:00'),
#     'Profit': 0.8999999999989043,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': 0.5999999999991594},
#   { 'Entry Price': 1.3642100000000001,
#     'Entry Time': Timestamp('2014-01-28 15:00:00'),
#     'Exit Price': 1.36724,
#     'Exit Time': Timestamp('2014-01-28 16:00:00'),
#     'Profit': 27.29999999999866,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': 20.999999999999577},
#   { 'Entry Price': 1.36626,
#     'Entry Time': Timestamp('2014-01-28 18:00:00'),
#     'Exit Price': 1.3651,
#     'Exit Time': Timestamp('2014-01-29 00:00:00'),
#     'Profit': -14.600000000000499,
#     'Trade Duration': 6,
#     'Type': 'BUY',
#     'reward': 3.8000000000001393},
#   { 'Entry Price': 1.3652799999999998,
#     'Entry Time': Timestamp('2014-01-29 02:00:00'),
#     'Exit Price': 1.36572,
#     'Exit Time': Timestamp('2014-01-29 04:00:00'),
#     'Profit': -7.40000000000218,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -8.700000000001815},
#   { 'Entry Price': 1.364,
#     'Entry Time': Timestamp('2014-01-29 16:00:00'),
#     'Exit Price': 1.36576,
#     'Exit Time': Timestamp('2014-01-30 02:00:00'),
#     'Profit': 14.599999999999838,
#     'Trade Duration': 10,
#     'Type': 'BUY',
#     'reward': 13.399999999998638},
#   { 'Entry Price': 1.3657700000000002,
#     'Entry Time': Timestamp('2014-01-30 03:00:00'),
#     'Exit Price': 1.36476,
#     'Exit Time': Timestamp('2014-01-30 06:00:00'),
#     'Profit': -13.100000000001774,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -13.000000000001119},
#   { 'Entry Price': 1.36443,
#     'Entry Time': Timestamp('2014-01-30 08:00:00'),
#     'Exit Price': 1.3596,
#     'Exit Time': Timestamp('2014-01-30 13:00:00'),
#     'Profit': -51.30000000000112,
#     'Trade Duration': 5,
#     'Type': 'BUY',
#     'reward': -43.40000000000043},
#   { 'Entry Price': 1.35625,
#     'Entry Time': Timestamp('2014-01-30 18:00:00'),
#     'Exit Price': 1.3551600000000001,
#     'Exit Time': Timestamp('2014-01-30 19:00:00'),
#     'Profit': -13.899999999998133,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -17.499999999999513},
#   { 'Entry Price': 1.35515,
#     'Entry Time': Timestamp('2014-01-30 20:00:00'),
#     'Exit Price': 1.35527,
#     'Exit Time': Timestamp('2014-01-30 23:00:00'),
#     'Profit': -1.8000000000010203,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -7.20000000000087},
#   { 'Entry Price': 1.35531,
#     'Entry Time': Timestamp('2014-01-31 00:00:00'),
#     'Exit Price': 1.35487,
#     'Exit Time': Timestamp('2014-01-31 04:00:00'),
#     'Profit': 1.3999999999999595,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -4.700000000000035}]
# Training period  2014-04-08 20:00:00 - 2014-05-30 23:00:00
# Average Reward is -3.4553191489362343
# SUMMARY STATISTICS
# Total Trades Taken:  187
# Total Reward:  -413.2000000000065
# Average Reward per Trade:  -2.209625668449233
# Win Ratio: 36.36363636363637 %
# [ { 'Entry Price': 1.37952,
#     'Entry Time': Timestamp('2014-04-08 21:00:00'),
#     'Exit Price': 1.37939,
#     'Exit Time': Timestamp('2014-04-09 00:00:00'),
#     'Profit': -1.6999999999981448,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -3.7999999999985796},
#   { 'Entry Price': 1.37942,
#     'Entry Time': Timestamp('2014-04-09 01:00:00'),
#     'Exit Price': 1.3790200000000001,
#     'Exit Time': Timestamp('2014-04-09 04:00:00'),
# ...
#   { 'Entry Price': 1.37158,
#     'Entry Time': Timestamp('2014-05-14 15:00:00'),
#     'Exit Price': 1.3713600000000001,
#     'Exit Time': Timestamp('2014-05-14 23:00:00'),
#     'Profit': -0.8000000000011305,
#     'Trade Duration': 8,
#     'Type': 'SELL',
#     'reward': 1.2000000000008697},
#   { 'Entry Price': 1.37137,
#     'Entry Time': Timestamp('2014-05-15 00:00:00'),
#     'Exit Price': 1.37165,
#     'Exit Time': Timestamp('2014-05-15 03:00:00'),
#     'Profit': -5.80000000000058,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -5.80000000000058},
#   { 'Entry Price': 1.37173,
#     'Entry Time': Timestamp('2014-05-15 05:00:00'),
#     'Exit Price': 1.37151,
#     'Exit Time': Timestamp('2014-05-15 09:00:00'),
#     'Profit': -5.1999999999988695,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -5.799999999998359},
#   { 'Entry Price': 1.3714899999999999,
#     'Entry Time': Timestamp('2014-05-15 10:00:00'),
#     'Exit Price': 1.36564,
#     'Exit Time': Timestamp('2014-05-15 13:00:00'),
#     'Profit': -61.499999999999105,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -63.199999999996926},
#   { 'Entry Price': 1.3660700000000001,
#     'Entry Time': Timestamp('2014-05-15 15:00:00'),
#     'Exit Price': 1.3671,
#     'Exit Time': Timestamp('2014-05-15 16:00:00'),
#     'Profit': 7.299999999998644,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -6.40000000000229},
#   { 'Entry Price': 1.3706,
#     'Entry Time': Timestamp('2014-05-15 20:00:00'),
#     'Exit Price': 1.3707200000000002,
#     'Exit Time': Timestamp('2014-05-15 22:00:00'),
#     'Profit': -4.2000000000012,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -11.500000000000174},
#   { 'Entry Price': 1.37131,
#     'Entry Time': Timestamp('2014-05-16 02:00:00'),
#     'Exit Price': 1.37163,
#     'Exit Time': Timestamp('2014-05-16 05:00:00'),
#     'Profit': -6.199999999998759,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -5.8999999999990145},
#   { 'Entry Price': 1.37164,
#     'Entry Time': Timestamp('2014-05-16 06:00:00'),
#     'Exit Price': 1.37117,
#     'Exit Time': Timestamp('2014-05-16 09:00:00'),
#     'Profit': 1.6999999999997044,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': 0.6000000000013799},
#   { 'Entry Price': 1.37173,
#     'Entry Time': Timestamp('2014-05-16 12:00:00'),
#     'Exit Price': 1.36989,
#     'Exit Time': Timestamp('2014-05-16 14:00:00'),
#     'Profit': -21.399999999998418,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -28.500000000000522},
#   { 'Entry Price': 1.3699,
#     'Entry Time': Timestamp('2014-05-16 15:00:00'),
#     'Exit Price': 1.37015,
#     'Exit Time': Timestamp('2014-05-16 19:00:00'),
#     'Profit': -5.500000000000835,
#     'Trade Duration': 4,
#     'Type': 'SELL',
#     'reward': -10.100000000002105},
#   { 'Entry Price': 1.37012,
#     'Entry Time': Timestamp('2014-05-16 20:00:00'),
#     'Exit Price': 1.37021,
#     'Exit Time': Timestamp('2014-05-19 02:00:00'),
#     'Profit': -2.1000000000007653,
#     'Trade Duration': 6,
#     'Type': 'BUY',
#     'reward': -8.699999999999594},
#   { 'Entry Price': 1.3701299999999998,
#     'Entry Time': Timestamp('2014-05-19 03:00:00'),
#     'Exit Price': 1.37069,
#     'Exit Time': Timestamp('2014-05-19 05:00:00'),
#     'Profit': 2.6000000000011596,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -2.6999999999980346},
#   { 'Entry Price': 1.37069,
#     'Entry Time': Timestamp('2014-05-19 06:00:00'),
#     'Exit Price': 1.37166,
#     'Exit Time': Timestamp('2014-05-19 10:00:00'),
#     'Profit': 6.700000000001374,
#     'Trade Duration': 4,
#     'Type': 'BUY',
#     'reward': -0.8999999999995651},
#   { 'Entry Price': 1.37074,
#     'Entry Time': Timestamp('2014-05-19 12:00:00'),
#     'Exit Price': 1.37147,
#     'Exit Time': Timestamp('2014-05-19 13:00:00'),
#     'Profit': 4.299999999998974,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': 8.599999999998278},
#   { 'Entry Price': 1.37228,
#     'Entry Time': Timestamp('2014-05-19 16:00:00'),
#     'Exit Price': 1.37172,
#     'Exit Time': Timestamp('2014-05-19 17:00:00'),
#     'Profit': 2.599999999998939,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 1.0999999999979941},
#   { 'Entry Price': 1.37086,
#     'Entry Time': Timestamp('2014-05-19 20:00:00'),
#     'Exit Price': 1.3707799999999999,
#     'Exit Time': Timestamp('2014-05-20 01:00:00'),
#     'Profit': -3.8000000000008,
#     'Trade Duration': 5,
#     'Type': 'BUY',
#     'reward': -3.4999999999988347},
#   { 'Entry Price': 1.37065,
#     'Entry Time': Timestamp('2014-05-20 05:00:00'),
#     'Exit Price': 1.37093,
#     'Exit Time': Timestamp('2014-05-20 07:00:00'),
#     'Profit': -0.1999999999994202,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 1.6000000000012697},
#   { 'Entry Price': 1.36944,
#     'Entry Time': Timestamp('2014-05-20 10:00:00'),
#     'Exit Price': 1.3684,
#     'Exit Time': Timestamp('2014-05-20 11:00:00'),
#     'Profit': -13.399999999999299,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.7999999999986898},
#   { 'Entry Price': 1.36839,
#     'Entry Time': Timestamp('2014-05-20 12:00:00'),
#     'Exit Price': 1.3699700000000001,
#     'Exit Time': Timestamp('2014-05-20 15:00:00'),
#     'Profit': 12.800000000001369,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 13.399999999998638},
#   { 'Entry Price': 1.3699700000000001,
#     'Entry Time': Timestamp('2014-05-20 16:00:00'),
#     'Exit Price': 1.3694600000000001,
#     'Exit Time': Timestamp('2014-05-20 17:00:00'),
#     'Profit': -8.100000000000104,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -3.7000000000023654},
#   { 'Entry Price': 1.37002,
#     'Entry Time': Timestamp('2014-05-20 19:00:00'),
#     'Exit Price': 1.36944,
#     'Exit Time': Timestamp('2014-05-20 20:00:00'),
#     'Profit': 2.8000000000002494,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': 8.700000000001154},
#   { 'Entry Price': 1.36942,
#     'Entry Time': Timestamp('2014-05-20 21:00:00'),
#     'Exit Price': 1.3700700000000001,
#     'Exit Time': Timestamp('2014-05-21 04:00:00'),
#     'Profit': 3.5000000000003944,
#     'Trade Duration': 7,
#     'Type': 'BUY',
#     'reward': 7.299999999998644},
#   { 'Entry Price': 1.37009,
#     'Entry Time': Timestamp('2014-05-21 05:00:00'),
#     'Exit Price': 1.37009,
#     'Exit Time': Timestamp('2014-05-21 06:00:00'),
#     'Profit': -3.0,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.1999999999992},
#   { 'Entry Price': 1.3701,
#     'Entry Time': Timestamp('2014-05-21 07:00:00'),
#     'Exit Price': 1.37153,
#     'Exit Time': Timestamp('2014-05-21 10:00:00'),
#     'Profit': 11.299999999998203,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': 13.299999999997983},
#   { 'Entry Price': 1.3713,
#     'Entry Time': Timestamp('2014-05-21 12:00:00'),
#     'Exit Price': 1.3677700000000002,
#     'Exit Time': Timestamp('2014-05-21 21:00:00'),
#     'Profit': 32.29999999999811,
#     'Trade Duration': 9,
#     'Type': 'SELL',
#     'reward': 42.999999999999375},
#   { 'Entry Price': 1.3677700000000002,
#     'Entry Time': Timestamp('2014-05-21 22:00:00'),
#     'Exit Price': 1.3664399999999999,
#     'Exit Time': Timestamp('2014-05-22 08:00:00'),
#     'Profit': 10.300000000002754,
#     'Trade Duration': 10,
#     'Type': 'SELL',
#     'reward': 3.0000000000015596},
#   { 'Entry Price': 1.36645,
#     'Entry Time': Timestamp('2014-05-22 09:00:00'),
#     'Exit Price': 1.36609,
#     'Exit Time': Timestamp('2014-05-22 15:00:00'),
#     'Profit': 0.5999999999991594,
#     'Trade Duration': 6,
#     'Type': 'SELL',
#     'reward': -7.900000000001015},
#   { 'Entry Price': 1.36479,
#     'Entry Time': Timestamp('2014-05-22 17:00:00'),
#     'Exit Price': 1.3654700000000002,
#     'Exit Time': Timestamp('2014-05-22 23:00:00'),
#     'Profit': -9.80000000000236,
#     'Trade Duration': 6,
#     'Type': 'SELL',
#     'reward': -10.300000000001194},
#   { 'Entry Price': 1.36548,
#     'Entry Time': Timestamp('2014-05-23 00:00:00'),
#     'Exit Price': 1.36544,
#     'Exit Time': Timestamp('2014-05-23 01:00:00'),
#     'Profit': -3.4000000000004,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.299999999999855},
#   { 'Entry Price': 1.36543,
#     'Entry Time': Timestamp('2014-05-23 02:00:00'),
#     'Exit Price': 1.3647200000000002,
#     'Exit Time': Timestamp('2014-05-23 04:00:00'),
#     'Profit': -10.099999999997664,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -16.19999999999988},
#   { 'Entry Price': 1.3647200000000002,
#     'Entry Time': Timestamp('2014-05-23 05:00:00'),
#     'Exit Price': 1.36487,
#     'Exit Time': Timestamp('2014-05-23 07:00:00'),
#     'Profit': -4.499999999998725,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -0.4999999999991651},
#   { 'Entry Price': 1.36435,
#     'Entry Time': Timestamp('2014-05-23 11:00:00'),
#     'Exit Price': 1.36309,
#     'Exit Time': Timestamp('2014-05-23 17:00:00'),
#     'Profit': 9.600000000000389,
#     'Trade Duration': 6,
#     'Type': 'SELL',
#     'reward': 9.999999999998568},
#   { 'Entry Price': 1.36307,
#     'Entry Time': Timestamp('2014-05-23 18:00:00'),
#     'Exit Price': 1.36322,
#     'Exit Time': Timestamp('2014-05-23 20:00:00'),
#     'Profit': -1.499999999999055,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -6.9999999999995595},
#   { 'Entry Price': 1.36321,
#     'Entry Time': Timestamp('2014-05-23 21:00:00'),
#     'Exit Price': 1.3623299999999998,
#     'Exit Time': Timestamp('2014-05-26 00:00:00'),
#     'Profit': -11.80000000000214,
#     'Trade Duration': 3,
#     'Type': 'BUY',
#     'reward': -5.100000000000435},
#   { 'Entry Price': 1.36263,
#     'Entry Time': Timestamp('2014-05-26 02:00:00'),
#     'Exit Price': 1.36172,
#     'Exit Time': Timestamp('2014-05-26 03:00:00'),
#     'Profit': -12.099999999999664,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.80000000000091},
#   { 'Entry Price': 1.36178,
#     'Entry Time': Timestamp('2014-05-26 08:00:00'),
#     'Exit Price': 1.36249,
#     'Exit Time': Timestamp('2014-05-26 09:00:00'),
#     'Profit': 4.099999999999884,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -3.304023721284466e-13},
#   { 'Entry Price': 1.36249,
#     'Entry Time': Timestamp('2014-05-26 10:00:00'),
#     'Exit Price': 1.36408,
#     'Exit Time': Timestamp('2014-05-26 11:00:00'),
#     'Profit': -18.899999999999803,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -18.499999999999403},
#   { 'Entry Price': 1.36408,
#     'Entry Time': Timestamp('2014-05-26 12:00:00'),
#     'Exit Price': 1.3639,
#     'Exit Time': Timestamp('2014-05-26 15:00:00'),
#     'Profit': -1.19999999999931,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -1.59999999999971},
#   { 'Entry Price': 1.3639,
#     'Entry Time': Timestamp('2014-05-26 16:00:00'),
#     'Exit Price': 1.36507,
#     'Exit Time': Timestamp('2014-05-26 17:00:00'),
#     'Profit': -14.700000000001154,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -5.700000000002145},
#   { 'Entry Price': 1.36505,
#     'Entry Time': Timestamp('2014-05-26 18:00:00'),
#     'Exit Price': 1.36459,
#     'Exit Time': Timestamp('2014-05-26 20:00:00'),
#     'Profit': 1.6000000000012697,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 3.2000000000006494},
#   { 'Entry Price': 1.36459,
#     'Entry Time': Timestamp('2014-05-26 21:00:00'),
#     'Exit Price': 1.36556,
#     'Exit Time': Timestamp('2014-05-27 06:00:00'),
#     'Profit': 6.700000000001374,
#     'Trade Duration': 9,
#     'Type': 'BUY',
#     'reward': 12.499999999999403},
#   { 'Entry Price': 1.36556,
#     'Entry Time': Timestamp('2014-05-27 07:00:00'),
#     'Exit Price': 1.36411,
#     'Exit Time': Timestamp('2014-05-27 14:00:00'),
#     'Profit': 11.500000000001734,
#     'Trade Duration': 7,
#     'Type': 'SELL',
#     'reward': 7.600000000000609},
#   { 'Entry Price': 1.3641,
#     'Entry Time': Timestamp('2014-05-27 15:00:00'),
#     'Exit Price': 1.3612,
#     'Exit Time': Timestamp('2014-05-27 17:00:00'),
#     'Profit': 26.000000000001247,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 1.6000000000012697},
#   { 'Entry Price': 1.3617,
#     'Entry Time': Timestamp('2014-05-27 19:00:00'),
#     'Exit Price': 1.3618,
#     'Exit Time': Timestamp('2014-05-27 20:00:00'),
#     'Profit': -3.99999999999989,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -1.0000000000002203},
#   { 'Entry Price': 1.3618,
#     'Entry Time': Timestamp('2014-05-27 21:00:00'),
#     'Exit Price': 1.3632600000000001,
#     'Exit Time': Timestamp('2014-05-27 23:00:00'),
#     'Profit': 11.600000000002389,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': 12.800000000001369},
#   { 'Entry Price': 1.3632799999999998,
#     'Entry Time': Timestamp('2014-05-28 00:00:00'),
#     'Exit Price': 1.3620299999999999,
#     'Exit Time': Timestamp('2014-05-28 11:00:00'),
#     'Profit': 9.499999999999734,
#     'Trade Duration': 11,
#     'Type': 'SELL',
#     'reward': 10.199999999997658},
#   { 'Entry Price': 1.36103,
#     'Entry Time': Timestamp('2014-05-28 15:00:00'),
#     'Exit Price': 1.3594600000000001,
#     'Exit Time': Timestamp('2014-05-28 17:00:00'),
#     'Profit': -18.699999999998493,
#     'Trade Duration': 2,
#     'Type': 'BUY',
#     'reward': -13.599999999998388},
#   { 'Entry Price': 1.35945,
#     'Entry Time': Timestamp('2014-05-28 18:00:00'),
#     'Exit Price': 1.35909,
#     'Exit Time': Timestamp('2014-05-28 19:00:00'),
#     'Profit': -6.60000000000138,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -4.100000000000545},
#   { 'Entry Price': 1.35924,
#     'Entry Time': Timestamp('2014-05-28 21:00:00'),
#     'Exit Price': 1.35932,
#     'Exit Time': Timestamp('2014-05-28 22:00:00'),
#     'Profit': -2.1999999999992,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -2.7999999999986898},
#   { 'Entry Price': 1.35897,
#     'Entry Time': Timestamp('2014-05-29 00:00:00'),
#     'Exit Price': 1.36056,
#     'Exit Time': Timestamp('2014-05-29 05:00:00'),
#     'Profit': -18.899999999999803,
#     'Trade Duration': 5,
#     'Type': 'SELL',
#     'reward': -10.099999999999884},
#   { 'Entry Price': 1.36047,
#     'Entry Time': Timestamp('2014-05-29 07:00:00'),
#     'Exit Price': 1.3616,
#     'Exit Time': Timestamp('2014-05-29 13:00:00'),
#     'Profit': 8.299999999998533,
#     'Trade Duration': 6,
#     'Type': 'BUY',
#     'reward': 8.900000000000244},
#   { 'Entry Price': 1.35992,
#     'Entry Time': Timestamp('2014-05-29 17:00:00'),
#     'Exit Price': 1.3608,
#     'Exit Time': Timestamp('2014-05-29 19:00:00'),
#     'Profit': -11.799999999999919,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': -10.699999999999374},
#   { 'Entry Price': 1.36079,
#     'Entry Time': Timestamp('2014-05-29 20:00:00'),
#     'Exit Price': 1.36046,
#     'Exit Time': Timestamp('2014-05-30 05:00:00'),
#     'Profit': -6.2999999999994145,
#     'Trade Duration': 9,
#     'Type': 'BUY',
#     'reward': -6.40000000000007},
#   { 'Entry Price': 1.36015,
#     'Entry Time': Timestamp('2014-05-30 09:00:00'),
#     'Exit Price': 1.36134,
#     'Exit Time': Timestamp('2014-05-30 12:00:00'),
#     'Profit': -14.900000000000244,
#     'Trade Duration': 3,
#     'Type': 'SELL',
#     'reward': -11.500000000000174},
#   { 'Entry Price': 1.3610200000000001,
#     'Entry Time': Timestamp('2014-05-30 14:00:00'),
#     'Exit Price': 1.36164,
#     'Exit Time': Timestamp('2014-05-30 15:00:00'),
#     'Profit': -9.199999999998429,
#     'Trade Duration': 1,
#     'Type': 'SELL',
#     'reward': -4.599999999997159},
#   { 'Entry Price': 1.36166,
#     'Entry Time': Timestamp('2014-05-30 16:00:00'),
#     'Exit Price': 1.3645100000000001,
#     'Exit Time': Timestamp('2014-05-30 17:00:00'),
#     'Profit': 25.500000000000192,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -1.3000000000021856},
#   { 'Entry Price': 1.36453,
#     'Entry Time': Timestamp('2014-05-30 18:00:00'),
#     'Exit Price': 1.36404,
#     'Exit Time': Timestamp('2014-05-30 19:00:00'),
#     'Profit': -7.900000000001015,
#     'Trade Duration': 1,
#     'Type': 'BUY',
#     'reward': -10.399999999999629},
#   { 'Entry Price': 1.36404,
#     'Entry Time': Timestamp('2014-05-30 20:00:00'),
#     'Exit Price': 1.3630200000000001,
#     'Exit Time': Timestamp('2014-05-30 22:00:00'),
#     'Profit': 7.1999999999979885,
#     'Trade Duration': 2,
#     'Type': 'SELL',
#     'reward': 5.299999999998864}]

# %%
! explorer .

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-a75182538ae9> in <module>()
# ----> 1 UT.save_state( './test_model/test_model')
#
# ~\Anaconda2\envs\gym_test\lib\site-packages\baselines\deepq\utils.py in save_state(fname)
#      14     os.makedirs(os.path.dirname(fname), exist_ok=True)
#      15     saver = tf.train.Saver()
# ---> 16     saver.save(tf.get_default_session(), fname)
#      17
#      18 # ================================================================
#
# ~\Anaconda2\envs\gym_test\lib\site-packages\tensorflow\python\training\saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1689     if (not context.executing_eagerly() and
#    1690         not isinstance(sess, session.SessionInterface)):
# -> 1691       raise TypeError("'sess' must be a Session; %s" % sess)
#    1692
#    1693     save_path_parent = os.path.dirname(save_path)
#
# TypeError: 'sess' must be a Session; None
